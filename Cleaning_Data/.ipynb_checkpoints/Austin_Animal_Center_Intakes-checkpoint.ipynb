# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
csv_path = "../Data/Austin_Animal_Center_Intakes.csv"
animal_center_intakes_df = pd.read_csv(csv_path)
animal_center_intakes_df
# Out:
#        Animal ID     Name                DateTime               MonthYear  \
# 0        A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1        A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2        A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3        A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4        A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# ...          ...      ...                     ...                     ...
# 124115   A828158     Odin  01/08/2021 07:01:00 PM  01/08/2021 07:01:00 PM
# 124116   A830183      NaN  03/03/2021 05:12:00 PM  03/03/2021 05:12:00 PM
# 124117   A830180     Gigi  03/03/2021 04:31:00 PM  03/03/2021 04:31:00 PM
# 124118   A830171      NaN  03/03/2021 05:13:00 PM  03/03/2021 05:13:00 PM
# 124119   A830181     Nona  03/03/2021 04:31:00 PM  03/03/2021 04:31:00 PM
#
#                               Found Location      Intake Type  \
# 0        2501 Magin Meadow Dr in Austin (TX)            Stray
# 1           9409 Bluegrass Dr in Austin (TX)            Stray
# 2         2818 Palomino Trail in Austin (TX)            Stray
# 3                                Austin (TX)            Stray
# 4              800 Grove Blvd in Austin (TX)            Stray
# ...                                      ...              ...
# 124115        2224 E Stassney in Austin (TX)            Stray
# 124116   6802 Bryonwood Drive in Austin (TX)            Stray
# 124117                           Austin (TX)  Owner Surrender
# 124118  1310 West Howard Lane in Austin (TX)            Stray
# 124119                           Austin (TX)  Owner Surrender
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 124115           Normal         Dog     Intact Male       10 months
# 124116          Medical         Dog   Intact Female         1 month
# 124117           Normal         Dog   Intact Female         9 years
# 124118           Normal         Dog   Intact Female          1 year
# 124119           Normal         Cat   Spayed Female         4 years
#
#                                          Breed                Color
# 0                                   Beagle Mix             Tricolor
# 1                     English Springer Spaniel          White/Liver
# 2                                  Basenji Mix          Sable/White
# 3                       Domestic Shorthair Mix               Calico
# 4        Doberman Pinsch/Australian Cattle Dog             Tan/Gray
# ...                                        ...                  ...
# 124115                          Rottweiler Mix            Black/Tan
# 124116                     Chihuahua Shorthair                White
# 124117  Australian Cattle Dog/Belgian Malinois  Brown Brindle/White
# 124118                         Plott Hound Mix  Brown Brindle/White
# 124119                  Domestic Shorthair Mix          White/Black
#
# [124120 rows x 12 columns]

# %%
animal_center_intakes_df.notnull().sum()
# Out:
# Animal ID           124120
# Name                 85069
# DateTime            124120
# MonthYear           124120
# Found Location      124120
# Intake Type         124120
# Intake Condition    124120
# Animal Type         124120
# Sex upon Intake     124119
# Age upon Intake     124120
# Breed               124120
# Color               124120
# dtype: int64

# %%
# Drop unncessary columns
intakes_df = animal_center_intakes_df.drop(columns=["Name", "MonthYear", "Found Location", "Color"])
intakes_df
# Out:
#        Animal ID                DateTime      Intake Type Intake Condition  \
# 0        A786884  01/03/2019 04:19:00 PM            Stray           Normal
# 1        A706918  07/05/2015 12:59:00 PM            Stray           Normal
# 2        A724273  04/14/2016 06:43:00 PM            Stray           Normal
# 3        A665644  10/21/2013 07:59:00 AM            Stray             Sick
# 4        A682524  06/29/2014 10:38:00 AM            Stray           Normal
# ...          ...                     ...              ...              ...
# 124115   A828158  01/08/2021 07:01:00 PM            Stray           Normal
# 124116   A830183  03/03/2021 05:12:00 PM            Stray          Medical
# 124117   A830180  03/03/2021 04:31:00 PM  Owner Surrender           Normal
# 124118   A830171  03/03/2021 05:13:00 PM            Stray           Normal
# 124119   A830181  03/03/2021 04:31:00 PM  Owner Surrender           Normal
#
#        Animal Type Sex upon Intake Age upon Intake  \
# 0              Dog   Neutered Male         2 years
# 1              Dog   Spayed Female         8 years
# 2              Dog     Intact Male       11 months
# 3              Cat   Intact Female         4 weeks
# 4              Dog   Neutered Male         4 years
# ...            ...             ...             ...
# 124115         Dog     Intact Male       10 months
# 124116         Dog   Intact Female         1 month
# 124117         Dog   Intact Female         9 years
# 124118         Dog   Intact Female          1 year
# 124119         Cat   Spayed Female         4 years
#
#                                          Breed
# 0                                   Beagle Mix
# 1                     English Springer Spaniel
# 2                                  Basenji Mix
# 3                       Domestic Shorthair Mix
# 4        Doberman Pinsch/Australian Cattle Dog
# ...                                        ...
# 124115                          Rottweiler Mix
# 124116                     Chihuahua Shorthair
# 124117  Australian Cattle Dog/Belgian Malinois
# 124118                         Plott Hound Mix
# 124119                  Domestic Shorthair Mix
#
# [124120 rows x 8 columns]

# %%
# Get data for cat
intakes_df = intakes_df.loc[(intakes_df["Animal Type"] == "Cat")]
intakes_df
# Out:
#        Animal ID                DateTime      Intake Type Intake Condition  \
# 3        A665644  10/21/2013 07:59:00 AM            Stray             Sick
# 8        A818975  06/18/2020 02:53:00 PM            Stray           Normal
# 9        A774147  06/11/2018 07:45:00 AM            Stray          Injured
# 10       A731435  08/08/2016 05:52:00 PM  Owner Surrender           Normal
# 14       A790209  03/06/2019 02:31:00 PM    Public Assist           Normal
# ...          ...                     ...              ...              ...
# 124085   A830122  03/02/2021 05:00:00 PM            Stray          Nursing
# 124088   A830113  03/02/2021 02:52:00 PM            Stray          Nursing
# 124091   A830137  03/03/2021 12:26:00 PM            Stray          Nursing
# 124106   A830157  03/03/2021 01:48:00 PM            Stray          Injured
# 124119   A830181  03/03/2021 04:31:00 PM  Owner Surrender           Normal
#
#        Animal Type Sex upon Intake Age upon Intake                   Breed
# 3              Cat   Intact Female         4 weeks  Domestic Shorthair Mix
# 8              Cat     Intact Male         4 weeks      Domestic Shorthair
# 9              Cat   Intact Female         4 weeks  Domestic Shorthair Mix
# 10             Cat   Neutered Male        5 months  Domestic Shorthair Mix
# 14             Cat   Intact Female         4 years  Domestic Shorthair Mix
# ...            ...             ...             ...                     ...
# 124085         Cat   Intact Female          3 days      Domestic Shorthair
# 124088         Cat   Intact Female         2 years      Domestic Shorthair
# 124091         Cat     Intact Male         3 weeks      Domestic Shorthair
# 124106         Cat     Intact Male        4 months  Domestic Shorthair Mix
# 124119         Cat   Spayed Female         4 years  Domestic Shorthair Mix
#
# [46455 rows x 8 columns]

# %%
intakes_df = intakes_df.dropna()
intakes_df.notnull().sum()
# Out:
# Animal ID           46455
# DateTime            46455
# Intake Type         46455
# Intake Condition    46455
# Animal Type         46455
# Sex upon Intake     46455
# Age upon Intake     46455
# Breed               46455
# dtype: int64

# %%
# check if there are duplicates in animal ID
intakes_df['Animal ID'].is_unique
# Out:
# False

# %%
# Drop duplicated animal ID
intakes_df = intakes_df.drop_duplicates(subset=['Animal ID'])

# %%
intakes_df["DateTime"] = pd.to_datetime(intakes_df["DateTime"]).dt.date
intakes_df
# Out:
#        Animal ID    DateTime      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray          Injured         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray          Nursing         Cat
# 124088   A830113  2021-03-02            Stray          Nursing         Cat
# 124091   A830137  2021-03-03            Stray          Nursing         Cat
# 124106   A830157  2021-03-03            Stray          Injured         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake Age upon Intake                   Breed
# 3        Intact Female         4 weeks  Domestic Shorthair Mix
# 8          Intact Male         4 weeks      Domestic Shorthair
# 9        Intact Female         4 weeks  Domestic Shorthair Mix
# 10       Neutered Male        5 months  Domestic Shorthair Mix
# 14       Intact Female         4 years  Domestic Shorthair Mix
# ...                ...             ...                     ...
# 124085   Intact Female          3 days      Domestic Shorthair
# 124088   Intact Female         2 years      Domestic Shorthair
# 124091     Intact Male         3 weeks      Domestic Shorthair
# 124106     Intact Male        4 months  Domestic Shorthair Mix
# 124119   Spayed Female         4 years  Domestic Shorthair Mix
#
# [44332 rows x 8 columns]

# %%
intakes_df.rename(columns = {'DateTime':'Intake Date'}, inplace = True)

# %%
intakes_df["Age upon Intake"].unique()
# Out:
# array(['4 weeks', '5 months', '4 years', '2 years', '14 years', '1 month',
#        '6 months', '4 days', '1 day', '2 weeks', '4 months', '15 years',
#        '8 years', '1 year', '2 months', '3 weeks', '3 months', '9 months',
#        '10 years', '10 months', '1 week', '3 years', '6 years', '5 years',
#        '1 weeks', '5 days', '7 months', '2 days', '7 years', '0 years',
#        '17 years', '3 days', '9 years', '13 years', '5 weeks', '8 months',
#        '12 years', '6 days', '11 years', '11 months', '16 years',
#        '18 years', '20 years', '22 years', '19 years'], dtype=object)

# %%
# Convert age into years
def convertAgeToFloat(inputAge):
# grab number & grab unit
    parsed = inputAge.split(" ")
    # ['5', 'days'] -> parsed[0] -> number, parsed[1] -> unit
    num = float(parsed[0])
    if (num < 0):
        return -1
    unit = parsed[1]
    divisor = 1
    if ('day' in unit):
        divisor = 365
    elif ('month' in unit):
        divisor = 12
    elif ('week' in unit):
        divisor = 52
    else:
        # assume the unit is years
        divisor = 1
    
    # if less than 1 year old, return 0
    if (num < divisor):
        return 0.0;
    
    # return age in years
    return num/divisor

# %%
intakes_df["Age upon Intake"] = intakes_df["Age upon Intake"].apply(convertAgeToFloat)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray          Injured         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray          Nursing         Cat
# 124088   A830113  2021-03-02            Stray          Nursing         Cat
# 124091   A830137  2021-03-03            Stray          Nursing         Cat
# 124106   A830157  2021-03-03            Stray          Injured         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake                   Breed
# 3        Intact Female              0.0  Domestic Shorthair Mix
# 8          Intact Male              0.0      Domestic Shorthair
# 9        Intact Female              0.0  Domestic Shorthair Mix
# 10       Neutered Male              0.0  Domestic Shorthair Mix
# 14       Intact Female              4.0  Domestic Shorthair Mix
# ...                ...              ...                     ...
# 124085   Intact Female              0.0      Domestic Shorthair
# 124088   Intact Female              2.0      Domestic Shorthair
# 124091     Intact Male              0.0      Domestic Shorthair
# 124106     Intact Male              0.0  Domestic Shorthair Mix
# 124119   Spayed Female              4.0  Domestic Shorthair Mix
#
# [44332 rows x 8 columns]

# %%
intakes_df["Age upon Intake"].unique()
# Out:
# array([ 0.,  4.,  2., 14., 15.,  8.,  1., 10.,  3.,  6.,  5.,  7., 17.,
#         9., 13., 12., 11., 16., 18., 20., 22., 19.])

# %%
# Drop invalid age (-1)
intakes_df.drop(intakes_df.index[intakes_df["Age upon Intake"] == -1], inplace=True)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray          Injured         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray          Nursing         Cat
# 124088   A830113  2021-03-02            Stray          Nursing         Cat
# 124091   A830137  2021-03-03            Stray          Nursing         Cat
# 124106   A830157  2021-03-03            Stray          Injured         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake                   Breed
# 3        Intact Female              0.0  Domestic Shorthair Mix
# 8          Intact Male              0.0      Domestic Shorthair
# 9        Intact Female              0.0  Domestic Shorthair Mix
# 10       Neutered Male              0.0  Domestic Shorthair Mix
# 14       Intact Female              4.0  Domestic Shorthair Mix
# ...                ...              ...                     ...
# 124085   Intact Female              0.0      Domestic Shorthair
# 124088   Intact Female              2.0      Domestic Shorthair
# 124091     Intact Male              0.0      Domestic Shorthair
# 124106     Intact Male              0.0  Domestic Shorthair Mix
# 124119   Spayed Female              4.0  Domestic Shorthair Mix
#
# [44332 rows x 8 columns]

# %%
# Rename age upon intake column
intakes_df.rename(columns = {'Age upon Intake':'Age upon Intake(years)'}, inplace = True)

# %%
intakes_df['Breed'].unique()
# Out:
# array(['Domestic Shorthair Mix', 'Domestic Shorthair',
#        'Domestic Longhair Mix', 'American Shorthair Mix',
#        'Domestic Medium Hair Mix', 'Domestic Medium Hair',
#        'Domestic Longhair', 'Russian Blue', 'Siamese Mix', 'Manx Mix',
#        'Maine Coon Mix', 'Bengal', 'Siamese', 'Angora Mix', 'Abyssinian',
#        'American Curl Shorthair/Siamese', 'Siamese/Domestic Shorthair',
#        'Munchkin Shorthair Mix', 'Domestic Shorthair/American Shorthair',
#        'Ragdoll Mix', 'Russian Blue Mix', 'Snowshoe Mix',
#        'Colorpoint Mix', 'Balinese Mix', 'Himalayan Mix', 'Birman Mix',
#        'American Shorthair', 'Abyssinian Mix', 'Balinese',
#        'Domestic Shorthair/Bengal', 'Domestic Medium Hair/Manx',
#        'Cymric Mix', 'Persian Mix', 'Tonkinese Mix',
#        'Japanese Bobtail Mix', 'Snowshoe', 'Himalayan',
#        'Turkish Angora Mix', 'Maine Coon',
#        'Domestic Shorthair/Domestic Shorthair', 'Oriental Sh',
#        'Domestic Medium Hair/Maine Coon', 'Manx/Domestic Shorthair',
#        'Pixiebob Shorthair Mix', 'Manx', 'Havana Brown',
#        'Norwegian Forest Cat Mix', 'Bengal Mix', 'Sphynx',
#        'Domestic Longhair/Persian', 'British Shorthair Mix', 'Ragdoll',
#        'Snowshoe/Ragdoll', 'Ocicat Mix', 'Burmese', 'Oriental Sh Mix',
#        'Devon Rex Mix', 'Bombay Mix', 'Cornish Rex Mix',
#        'American Curl Shorthair Mix', 'Domestic Shorthair/Manx',
#        'Bengal/Domestic Shorthair', 'Ragdoll/Munchkin Longhair',
#        'Domestic Medium Hair/Siamese', 'Chartreux Mix',
#        'Domestic Shorthair/Maine Coon', 'Turkish Van Mix',
#        'Domestic Shorthair/Siamese', 'Scottish Fold Mix',
#        'Havana Brown Mix', 'Siamese/Angora',
#        'Domestic Longhair/Domestic Longhair', 'Persian',
#        'Siamese/Japanese Bobtail', 'Burmese Mix', 'Domestic Longhair/Rex',
#        'American Curl Shorthair', 'British Shorthair', 'Devon Rex',
#        'Munchkin Longhair Mix', 'Pixiebob Shorthair', 'Angora/Persian',
#        'Manx/Domestic Longhair', 'Snowshoe/Domestic Shorthair',
#        'Manx/Domestic Medium Hair', 'Domestic Longhair/Russian Blue',
#        'Japanese Bobtail/American Curl Shorthair', 'Exotic Shorthair Mix',
#        'American Wirehair Mix', 'Domestic Shorthair/Abyssinian',
#        'Snowshoe/Siamese', 'Tonkinese', 'Javanese Mix',
#        'Domestic Shorthair/British Shorthair', 'Cornish Rex',
#        'Scottish Fold/Domestic Shorthair', 'Ragdoll/Snowshoe',
#        'Domestic Longhair/Siamese', 'Manx/Siamese', 'Turkish Angora'],
#       dtype=object)

# %%
# Clean "Breed" column
# Remove breed name after "/" and change to "Mix"
intakes_df['Breed'] = intakes_df['Breed'].apply(lambda x: x.split("/")[0] + " Mix" if "/" in x else x)
intakes_df['Breed'].unique()
# Out:
# array(['Domestic Shorthair Mix', 'Domestic Shorthair',
#        'Domestic Longhair Mix', 'American Shorthair Mix',
#        'Domestic Medium Hair Mix', 'Domestic Medium Hair',
#        'Domestic Longhair', 'Russian Blue', 'Siamese Mix', 'Manx Mix',
#        'Maine Coon Mix', 'Bengal', 'Siamese', 'Angora Mix', 'Abyssinian',
#        'American Curl Shorthair Mix', 'Munchkin Shorthair Mix',
#        'Ragdoll Mix', 'Russian Blue Mix', 'Snowshoe Mix',
#        'Colorpoint Mix', 'Balinese Mix', 'Himalayan Mix', 'Birman Mix',
#        'American Shorthair', 'Abyssinian Mix', 'Balinese', 'Cymric Mix',
#        'Persian Mix', 'Tonkinese Mix', 'Japanese Bobtail Mix', 'Snowshoe',
#        'Himalayan', 'Turkish Angora Mix', 'Maine Coon', 'Oriental Sh',
#        'Pixiebob Shorthair Mix', 'Manx', 'Havana Brown',
#        'Norwegian Forest Cat Mix', 'Bengal Mix', 'Sphynx',
#        'British Shorthair Mix', 'Ragdoll', 'Ocicat Mix', 'Burmese',
#        'Oriental Sh Mix', 'Devon Rex Mix', 'Bombay Mix',
#        'Cornish Rex Mix', 'Chartreux Mix', 'Turkish Van Mix',
#        'Scottish Fold Mix', 'Havana Brown Mix', 'Persian', 'Burmese Mix',
#        'American Curl Shorthair', 'British Shorthair', 'Devon Rex',
#        'Munchkin Longhair Mix', 'Pixiebob Shorthair',
#        'Exotic Shorthair Mix', 'American Wirehair Mix', 'Tonkinese',
#        'Javanese Mix', 'Cornish Rex', 'Turkish Angora'], dtype=object)

# %%
intakes_df["Sex upon Intake"].unique()
# Out:
# array(['Intact Female', 'Intact Male', 'Neutered Male', 'Unknown',
#        'Spayed Female'], dtype=object)

# %%
# Clean "Sex upon Intake" column
def convertSex(inputSex):
    if ('Male' in inputSex):
        return 'Male'
    elif ('Female' in inputSex):
        return 'Female'
    else: 
        return 'Unknown'

# %%
intakes_df["Sex upon Intake"] = intakes_df["Sex upon Intake"].apply(convertSex)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray          Injured         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray          Nursing         Cat
# 124088   A830113  2021-03-02            Stray          Nursing         Cat
# 124091   A830137  2021-03-03            Stray          Nursing         Cat
# 124106   A830157  2021-03-03            Stray          Injured         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake(years)                   Breed
# 3               Female                     0.0  Domestic Shorthair Mix
# 8                 Male                     0.0      Domestic Shorthair
# 9               Female                     0.0  Domestic Shorthair Mix
# 10                Male                     0.0  Domestic Shorthair Mix
# 14              Female                     4.0  Domestic Shorthair Mix
# ...                ...                     ...                     ...
# 124085          Female                     0.0      Domestic Shorthair
# 124088          Female                     2.0      Domestic Shorthair
# 124091            Male                     0.0      Domestic Shorthair
# 124106            Male                     0.0  Domestic Shorthair Mix
# 124119          Female                     4.0  Domestic Shorthair Mix
#
# [44332 rows x 8 columns]

# %%
# Drop unknown sex
intakes_df.drop(intakes_df.index[intakes_df["Sex upon Intake"] == "Unknown"], inplace=True)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray          Injured         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray          Nursing         Cat
# 124088   A830113  2021-03-02            Stray          Nursing         Cat
# 124091   A830137  2021-03-03            Stray          Nursing         Cat
# 124106   A830157  2021-03-03            Stray          Injured         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake(years)                   Breed
# 3               Female                     0.0  Domestic Shorthair Mix
# 8                 Male                     0.0      Domestic Shorthair
# 9               Female                     0.0  Domestic Shorthair Mix
# 10                Male                     0.0  Domestic Shorthair Mix
# 14              Female                     4.0  Domestic Shorthair Mix
# ...                ...                     ...                     ...
# 124085          Female                     0.0      Domestic Shorthair
# 124088          Female                     2.0      Domestic Shorthair
# 124091            Male                     0.0      Domestic Shorthair
# 124106            Male                     0.0  Domestic Shorthair Mix
# 124119          Female                     4.0  Domestic Shorthair Mix
#
# [40455 rows x 8 columns]

# %%
intakes_df["Intake Type"].unique()
# Out:
# array(['Stray', 'Owner Surrender', 'Public Assist', 'Abandoned',
#        'Euthanasia Request'], dtype=object)

# %%
intakes_df["Intake Condition"].unique()
# Out:
# array(['Sick', 'Normal', 'Injured', 'Nursing', 'Other', 'Feral',
#        'Medical', 'Aged', 'Pregnant', 'Behavior'], dtype=object)

# %%
# Clean "Intake Condition" column
def convertCondition(inputCondition):
    if ('Sick' in inputCondition) or ('Injured' in inputCondition) or ('Nursing' in inputCondition) or ('Medical' in inputCondition):
        return 'Sick'
    
    if ('Normal' in inputCondition):
        return 'Normal'
    
    if ('Aged' in inputCondition):
        return 'Aged'
    
    if ('Feral' in inputCondition):
        return 'Feral'
    
    if ('Pregnant' in inputCondition):
        return 'Pregnant'
    
    if ('Behavior' in inputCondition):
        return 'Behavior'
    
    return 'Other'

# %%
intakes_df["Intake Condition"] = intakes_df["Intake Condition"].apply(convertCondition)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray             Sick         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray             Sick         Cat
# 124088   A830113  2021-03-02            Stray             Sick         Cat
# 124091   A830137  2021-03-03            Stray             Sick         Cat
# 124106   A830157  2021-03-03            Stray             Sick         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake(years)                   Breed
# 3               Female                     0.0  Domestic Shorthair Mix
# 8                 Male                     0.0      Domestic Shorthair
# 9               Female                     0.0  Domestic Shorthair Mix
# 10                Male                     0.0  Domestic Shorthair Mix
# 14              Female                     4.0  Domestic Shorthair Mix
# ...                ...                     ...                     ...
# 124085          Female                     0.0      Domestic Shorthair
# 124088          Female                     2.0      Domestic Shorthair
# 124091            Male                     0.0      Domestic Shorthair
# 124106            Male                     0.0  Domestic Shorthair Mix
# 124119          Female                     4.0  Domestic Shorthair Mix
#
# [40455 rows x 8 columns]

# %%
# Drop unknown condition
intakes_df.drop(intakes_df.index[intakes_df["Intake Condition"] == "Other"], inplace=True)
intakes_df
# Out:
#        Animal ID Intake Date      Intake Type Intake Condition Animal Type  \
# 3        A665644  2013-10-21            Stray             Sick         Cat
# 8        A818975  2020-06-18            Stray           Normal         Cat
# 9        A774147  2018-06-11            Stray             Sick         Cat
# 10       A731435  2016-08-08  Owner Surrender           Normal         Cat
# 14       A790209  2019-03-06    Public Assist           Normal         Cat
# ...          ...         ...              ...              ...         ...
# 124085   A830122  2021-03-02            Stray             Sick         Cat
# 124088   A830113  2021-03-02            Stray             Sick         Cat
# 124091   A830137  2021-03-03            Stray             Sick         Cat
# 124106   A830157  2021-03-03            Stray             Sick         Cat
# 124119   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#        Sex upon Intake  Age upon Intake(years)                   Breed
# 3               Female                     0.0  Domestic Shorthair Mix
# 8                 Male                     0.0      Domestic Shorthair
# 9               Female                     0.0  Domestic Shorthair Mix
# 10                Male                     0.0  Domestic Shorthair Mix
# 14              Female                     4.0  Domestic Shorthair Mix
# ...                ...                     ...                     ...
# 124085          Female                     0.0      Domestic Shorthair
# 124088          Female                     2.0      Domestic Shorthair
# 124091            Male                     0.0      Domestic Shorthair
# 124106            Male                     0.0  Domestic Shorthair Mix
# 124119          Female                     4.0  Domestic Shorthair Mix
#
# [40372 rows x 8 columns]

# %%
intakes_df["Intake Condition"].unique()
# Out:
# array(['Sick', 'Normal', 'Feral', 'Aged', 'Pregnant', 'Behavior'],
#       dtype=object)

# %%
intakes_df.to_csv('../Data/clean_intakes.csv', index = False)
