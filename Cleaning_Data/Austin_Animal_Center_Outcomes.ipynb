# %%
import numpy as np
import pandas as pd

# %%
csv_path = "../Data/Austin_Animal_Center_Outcomes.csv"
animal_center_outcomes_df = pd.read_csv(csv_path)
animal_center_outcomes_df
# Out:
#        Animal ID   Name                DateTime               MonthYear  \
# 0        A794011  Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1        A776359  Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2        A821648    NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3        A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4        A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
# ...          ...    ...                     ...                     ...
# 124486   A828810  *Rory  03/03/2021 04:20:00 PM  03/03/2021 04:20:00 PM
# 124487   A791377   Bolt  12/28/2020 03:49:00 PM  12/28/2020 03:49:00 PM
# 124488   A829611  Chief  03/03/2021 04:59:00 PM  03/03/2021 04:59:00 PM
# 124489   A829964    NaN  03/03/2021 05:57:00 PM  03/03/2021 05:57:00 PM
# 124490   A828158   Odin  03/03/2021 05:19:00 PM  03/03/2021 05:19:00 PM
#
#        Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 0         05/02/2017        Rto-Adopt             NaN         Cat
# 1         07/12/2017         Adoption             NaN         Dog
# 2         08/16/2019       Euthanasia             NaN       Other
# 3         10/08/2015         Adoption             NaN         Dog
# 4         03/12/2014         Transfer         Partner         Cat
# ...              ...              ...             ...         ...
# 124486    03/26/2020         Adoption             NaN         Dog
# 124487    01/14/2019  Return to Owner             NaN         Dog
# 124488    02/17/2012        Rto-Adopt             NaN         Cat
# 124489    11/27/2020         Adoption             NaN         Dog
# 124490    03/09/2020         Adoption             NaN         Dog
#
#        Sex upon Outcome Age upon Outcome  \
# 0         Neutered Male          2 years
# 1         Neutered Male           1 year
# 2               Unknown           1 year
# 3         Neutered Male         4 months
# 4           Intact Male           6 days
# ...                 ...              ...
# 124486    Spayed Female        11 months
# 124487    Neutered Male           1 year
# 124488    Neutered Male          9 years
# 124489    Neutered Male         3 months
# 124490    Neutered Male        11 months
#
#                                                     Breed              Color
# 0                                  Domestic Shorthair Mix  Brown Tabby/White
# 1                                 Chihuahua Shorthair Mix        White/Brown
# 2                                                 Raccoon               Gray
# 3                      Anatol Shepherd/Labrador Retriever               Buff
# 4                                  Domestic Shorthair Mix       Orange Tabby
# ...                                                   ...                ...
# 124486  Chihuahua Shorthair/American Staffordshire Ter...          Brown/Tan
# 124487                                 Siberian Husky Mix              White
# 124488                                 Domestic Shorthair       Orange Tabby
# 124489                                 Labrador Retriever              Cream
# 124490                                     Rottweiler Mix          Black/Tan
#
# [124491 rows x 12 columns]

# %%
animal_center_outcomes_df.notnull().sum()
# Out:
# Animal ID           124491
# Name                 85466
# DateTime            124491
# MonthYear           124491
# Date of Birth       124491
# Outcome Type        124471
# Outcome Subtype      57308
# Animal Type         124491
# Sex upon Outcome    124490
# Age upon Outcome    124486
# Breed               124491
# Color               124491
# dtype: int64

# %%
# Drop unncessary columns
outcomes_df = animal_center_outcomes_df.drop(columns=["Name", "MonthYear", "Date of Birth", "Outcome Subtype", "Sex upon Outcome", "Breed", "Color"])
outcomes_df
# Out:
#        Animal ID                DateTime     Outcome Type Animal Type  \
# 0        A794011  05/08/2019 06:20:00 PM        Rto-Adopt         Cat
# 1        A776359  07/18/2018 04:02:00 PM         Adoption         Dog
# 2        A821648  08/16/2020 11:38:00 AM       Euthanasia       Other
# 3        A720371  02/13/2016 05:59:00 PM         Adoption         Dog
# 4        A674754  03/18/2014 11:47:00 AM         Transfer         Cat
# ...          ...                     ...              ...         ...
# 124486   A828810  03/03/2021 04:20:00 PM         Adoption         Dog
# 124487   A791377  12/28/2020 03:49:00 PM  Return to Owner         Dog
# 124488   A829611  03/03/2021 04:59:00 PM        Rto-Adopt         Cat
# 124489   A829964  03/03/2021 05:57:00 PM         Adoption         Dog
# 124490   A828158  03/03/2021 05:19:00 PM         Adoption         Dog
#
#        Age upon Outcome
# 0               2 years
# 1                1 year
# 2                1 year
# 3              4 months
# 4                6 days
# ...                 ...
# 124486        11 months
# 124487           1 year
# 124488          9 years
# 124489         3 months
# 124490        11 months
#
# [124491 rows x 5 columns]

# %%
# Filter for cat
outcomes_df = outcomes_df.loc[(outcomes_df["Animal Type"] == "Cat")]
outcomes_df
# Out:
#        Animal ID                DateTime Outcome Type Animal Type  \
# 0        A794011  05/08/2019 06:20:00 PM    Rto-Adopt         Cat
# 4        A674754  03/18/2014 11:47:00 AM     Transfer         Cat
# 7        A689724  10/18/2014 06:52:00 PM     Adoption         Cat
# 8        A680969  08/05/2014 04:59:00 PM     Adoption         Cat
# 9        A684617  07/27/2014 09:00:00 AM     Transfer         Cat
# ...          ...                     ...          ...         ...
# 124460   A829816  03/02/2021 05:44:00 PM     Adoption         Cat
# 124470   A822366  03/03/2021 12:04:00 PM     Adoption         Cat
# 124484   A829561  03/03/2021 04:21:00 PM     Transfer         Cat
# 124485   A829517  03/03/2021 04:21:00 PM     Transfer         Cat
# 124488   A829611  03/03/2021 04:59:00 PM    Rto-Adopt         Cat
#
#        Age upon Outcome
# 0               2 years
# 4                6 days
# 7              2 months
# 8              2 months
# 9               2 years
# ...                 ...
# 124460           1 year
# 124470          3 years
# 124484         6 months
# 124485           1 year
# 124488          9 years
#
# [46762 rows x 5 columns]

# %%
# Drop animal type column
outcomes_df = outcomes_df.drop(columns=["Animal Type"])

# %%
outcomes_df = outcomes_df.dropna()
outcomes_df.notnull().sum()
# Out:
# Animal ID           46759
# DateTime            46759
# Outcome Type        46759
# Age upon Outcome    46759
# dtype: int64

# %%
# check if there are duplicates in animal ID
outcomes_df['Animal ID'].is_unique
# Out:
# False

# %%
# Drop duplicated animal ID
outcomes_df = outcomes_df.drop_duplicates(subset=['Animal ID'])

# %%
outcomes_df["DateTime"] = pd.to_datetime(outcomes_df["DateTime"]).dt.date
outcomes_df
# Out:
#        Animal ID    DateTime Outcome Type Age upon Outcome
# 0        A794011  2019-05-08    Rto-Adopt          2 years
# 4        A674754  2014-03-18     Transfer           6 days
# 7        A689724  2014-10-18     Adoption         2 months
# 8        A680969  2014-08-05     Adoption         2 months
# 9        A684617  2014-07-27     Transfer          2 years
# ...          ...         ...          ...              ...
# 124460   A829816  2021-03-02     Adoption           1 year
# 124470   A822366  2021-03-03     Adoption          3 years
# 124484   A829561  2021-03-03     Transfer         6 months
# 124485   A829517  2021-03-03     Transfer           1 year
# 124488   A829611  2021-03-03    Rto-Adopt          9 years
#
# [44607 rows x 4 columns]

# %%
outcomes_df.rename(columns = {'DateTime':'Outcome Date'}, inplace = True)

# %%
outcomes_df["Age upon Outcome"].unique()
# Out:
# array(['2 years', '6 days', '2 months', '7 years', '2 days', '3 weeks',
#        '9 months', '4 weeks', '3 months', '6 months', '1 month',
#        '1 weeks', '5 years', '1 year', '4 months', '10 years', '5 months',
#        '5 days', '8 years', '15 years', '4 days', '2 weeks', '4 years',
#        '16 years', '1 day', '11 years', '3 years', '10 months',
#        '7 months', '13 years', '12 years', '1 week', '6 years', '3 days',
#        '8 months', '14 years', '9 years', '5 weeks', '11 months',
#        '0 years', '20 years', '22 years', '19 years', '17 years',
#        '18 years'], dtype=object)

# %%
# Convert age into years
def convertAgeToFloat(inputAge):
# grab number & grab unit
    parsed = inputAge.split(" ")
    # ['5', 'days'] -> parsed[0] -> number, parsed[1] -> unit
    num = float(parsed[0])
    if (num < 0):
        return -1
    unit = parsed[1]
    divisor = 1
    if ('day' in unit):
        divisor = 365
    elif ('month' in unit):
        divisor = 12
    elif ('week' in unit):
        divisor = 52
    else:
    # assume the unit is years
        divisor = 1
    if (num < divisor):
        return 0.0;
    return num/divisor

# %%
outcomes_df["Age upon Outcome"] = outcomes_df["Age upon Outcome"].apply(convertAgeToFloat)
outcomes_df
# Out:
#        Animal ID Outcome Date Outcome Type  Age upon Outcome
# 0        A794011   2019-05-08    Rto-Adopt               2.0
# 4        A674754   2014-03-18     Transfer               0.0
# 7        A689724   2014-10-18     Adoption               0.0
# 8        A680969   2014-08-05     Adoption               0.0
# 9        A684617   2014-07-27     Transfer               2.0
# ...          ...          ...          ...               ...
# 124460   A829816   2021-03-02     Adoption               1.0
# 124470   A822366   2021-03-03     Adoption               3.0
# 124484   A829561   2021-03-03     Transfer               0.0
# 124485   A829517   2021-03-03     Transfer               1.0
# 124488   A829611   2021-03-03    Rto-Adopt               9.0
#
# [44607 rows x 4 columns]

# %%
outcomes_df["Age upon Outcome"].unique()
# Out:
# array([ 2.,  0.,  7.,  5.,  1., 10.,  8., 15.,  4., 16., 11.,  3., 13.,
#        12.,  6., 14.,  9., 20., 22., 19., 17., 18.])

# %%
# Drop invalid age (-1)
outcomes_df.drop(outcomes_df.index[outcomes_df["Age upon Outcome"] == -1], inplace=True)
outcomes_df
# Out:
#        Animal ID Outcome Date Outcome Type  Age upon Outcome
# 0        A794011   2019-05-08    Rto-Adopt               2.0
# 4        A674754   2014-03-18     Transfer               0.0
# 7        A689724   2014-10-18     Adoption               0.0
# 8        A680969   2014-08-05     Adoption               0.0
# 9        A684617   2014-07-27     Transfer               2.0
# ...          ...          ...          ...               ...
# 124460   A829816   2021-03-02     Adoption               1.0
# 124470   A822366   2021-03-03     Adoption               3.0
# 124484   A829561   2021-03-03     Transfer               0.0
# 124485   A829517   2021-03-03     Transfer               1.0
# 124488   A829611   2021-03-03    Rto-Adopt               9.0
#
# [44607 rows x 4 columns]

# %%
# Rename age upon outcome column
outcomes_df.rename(columns = {'Age upon Outcome':'Age upon Outcomes(years)'}, inplace = True)

# %%
outcomes_df["Outcome Type"].unique()
# Out:
# array(['Rto-Adopt', 'Transfer', 'Adoption', 'Return to Owner',
#        'Euthanasia', 'Died', 'Disposal', 'Missing', 'Relocate'],
#       dtype=object)

# %%
# Clean "Outcome Type" column
def convertOutcome(inputOutcome):
    if ('Adopt' in inputOutcome) or ('Return' in inputOutcome):
        return 'Adoption or RTO'
    elif ('Transfer' in inputOutcome) or ('Relocate' in inputOutcome):
        return 'Transfer'
    elif ('Died' in inputOutcome) or ('Disposal' in inputOutcome) or ('Missing' in inputOutcome):
        return 'Died or Missing'
    elif ('Euthanasia' in inputOutcome):
        return 'Euthanasia'

# %%
outcomes_df["Outcome Type"] = outcomes_df["Outcome Type"].apply(convertOutcome)
outcomes_df
# Out:
#        Animal ID Outcome Date     Outcome Type  Age upon Outcomes(years)
# 0        A794011   2019-05-08  Adoption or RTO                       2.0
# 4        A674754   2014-03-18         Transfer                       0.0
# 7        A689724   2014-10-18  Adoption or RTO                       0.0
# 8        A680969   2014-08-05  Adoption or RTO                       0.0
# 9        A684617   2014-07-27         Transfer                       2.0
# ...          ...          ...              ...                       ...
# 124460   A829816   2021-03-02  Adoption or RTO                       1.0
# 124470   A822366   2021-03-03  Adoption or RTO                       3.0
# 124484   A829561   2021-03-03         Transfer                       0.0
# 124485   A829517   2021-03-03         Transfer                       1.0
# 124488   A829611   2021-03-03  Adoption or RTO                       9.0
#
# [44607 rows x 4 columns]

# %%
outcomes_df["Outcome Type"].unique()
# Out:
# array(['Adoption or RTO', 'Transfer', 'Euthanasia', 'Died or Missing'],
#       dtype=object)

# %%
outcomes_df.to_csv('../Data/clean_outcomes.csv', index = False)
