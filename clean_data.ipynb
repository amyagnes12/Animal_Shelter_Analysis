# %%
import numpy as np
import pandas as pd

# %%
from sqlalchemy import create_engine
from config import db_password
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Animal_Shelter"
engine = create_engine(db_string)

# %%
intakes_outcomes_df = pd.read_sql_table('intakes_outcomes', con=engine)
intakes_outcomes_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 0       A720371  2016-02-08            Stray           Normal         Dog
# 1       A659412  2018-06-13  Owner Surrender           Normal         Dog
# 2       A814515  2020-03-01  Owner Surrender           Normal         Dog
# 3       A689724  2014-10-08            Stray           Normal         Cat
# 4       A680969  2014-06-10            Stray             Sick         Cat
# ...         ...         ...              ...              ...         ...
# 99196   A828252  2021-01-12            Stray           Normal         Cat
# 99197   A828480  2021-01-18    Public Assist           Normal         Dog
# 99198   A791070  2019-03-31    Public Assist           Normal         Dog
# 99199   A820274  2020-07-16            Stray           Normal         Dog
# 99200   A829667  2021-02-20            Stray           Normal         Dog
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# 0                Male              0.0   2016-02-13  Adoption or RTO
# 1              Female              5.0   2020-10-05  Adoption or RTO
# 2                Male              2.0   2020-05-06  Adoption or RTO
# 3                Male              0.0   2014-10-18  Adoption or RTO
# 4                Male              0.0   2014-08-05  Adoption or RTO
# ...               ...              ...          ...              ...
# 99196          Female              0.0          NaT             None
# 99197          Female              2.0          NaT             None
# 99198            Male              1.0          NaT             None
# 99199            Male              6.0          NaT             None
# 99200            Male              2.0          NaT             None
#
#        age_upon_outcome
# 0                   0.0
# 1                   7.0
# 2                   2.0
# 3                   0.0
# 4                   0.0
# ...                 ...
# 99196               NaN
# 99197               NaN
# 99198               NaN
# 99199               NaN
# 99200               NaN
#
# [99201 rows x 10 columns]

# %%
intakes_outcomes_df.dtypes
# Out:
# animal_id                   object
# intake_date         datetime64[ns]
# intake_type                 object
# intake_condition            object
# animal_type                 object
# sex_upon_intake             object
# age_upon_intake            float64
# outcome_date        datetime64[ns]
# outcome_type                object
# age_upon_outcome           float64
# dtype: object

# %%
# Count number of NaN values
intakes_outcomes_df.isnull().sum(axis = 0)
# Out:
# animal_id             0
# intake_date           0
# intake_type           0
# intake_condition      0
# animal_type           0
# sex_upon_intake       0
# age_upon_intake       0
# outcome_date        421
# outcome_type        421
# age_upon_outcome    421
# dtype: int64

# %%
# Replace NaN values 
intakes_outcomes_df[['outcome_type']] = intakes_outcomes_df[['outcome_type']].fillna('Still in center')
intakes_outcomes_df['outcome_date'] = intakes_outcomes_df['outcome_date'].fillna(intakes_outcomes_df['intake_date'])
intakes_outcomes_df['age_upon_outcome'] = intakes_outcomes_df['age_upon_outcome'].fillna(intakes_outcomes_df['age_upon_intake'])

# %%
intakes_outcomes_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 0       A720371  2016-02-08            Stray           Normal         Dog
# 1       A659412  2018-06-13  Owner Surrender           Normal         Dog
# 2       A814515  2020-03-01  Owner Surrender           Normal         Dog
# 3       A689724  2014-10-08            Stray           Normal         Cat
# 4       A680969  2014-06-10            Stray             Sick         Cat
# ...         ...         ...              ...              ...         ...
# 99196   A828252  2021-01-12            Stray           Normal         Cat
# 99197   A828480  2021-01-18    Public Assist           Normal         Dog
# 99198   A791070  2019-03-31    Public Assist           Normal         Dog
# 99199   A820274  2020-07-16            Stray           Normal         Dog
# 99200   A829667  2021-02-20            Stray           Normal         Dog
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# 0                Male              0.0   2016-02-13  Adoption or RTO
# 1              Female              5.0   2020-10-05  Adoption or RTO
# 2                Male              2.0   2020-05-06  Adoption or RTO
# 3                Male              0.0   2014-10-18  Adoption or RTO
# 4                Male              0.0   2014-08-05  Adoption or RTO
# ...               ...              ...          ...              ...
# 99196          Female              0.0   2021-01-12  Still in center
# 99197          Female              2.0   2021-01-18  Still in center
# 99198            Male              1.0   2019-03-31  Still in center
# 99199            Male              6.0   2020-07-16  Still in center
# 99200            Male              2.0   2021-02-20  Still in center
#
#        age_upon_outcome
# 0                   0.0
# 1                   7.0
# 2                   2.0
# 3                   0.0
# 4                   0.0
# ...                 ...
# 99196               0.0
# 99197               2.0
# 99198               1.0
# 99199               6.0
# 99200               2.0
#
# [99201 rows x 10 columns]

# %%
intakes_outcomes_df.dtypes
# Out:
# animal_id                   object
# intake_date         datetime64[ns]
# intake_type                 object
# intake_condition            object
# animal_type                 object
# sex_upon_intake             object
# age_upon_intake            float64
# outcome_date        datetime64[ns]
# outcome_type                object
# age_upon_outcome           float64
# dtype: object

# %%
# convert "age_upon_outcome" to int
intakes_outcomes_df['age_upon_outcome'] = intakes_outcomes_df['age_upon_outcome'].astype(int)

# %%
# convert object to date
intakes_outcomes_df['intake_date'] = pd.to_datetime(intakes_outcomes_df['intake_date'])
intakes_outcomes_df['outcome_date'] = pd.to_datetime(intakes_outcomes_df['outcome_date'])

# %%
# create new column to calculate how long each animal stayed in the center
intakes_outcomes_df['days_in_center'] = (intakes_outcomes_df['outcome_date'] - intakes_outcomes_df['intake_date']).dt.days

# %%
intakes_outcomes_df["days_in_center"].unique()
# Out:
# array([    5,   845,    66, ..., -1100,  -655, -2219])

# %%
# Drop negative(invalid) values on "days in center"
intakes_outcomes_df.drop(intakes_outcomes_df[intakes_outcomes_df['days_in_center'] < 0 ].index , inplace=True)

# %%
# Sort data by intake date
intakes_outcomes_df = intakes_outcomes_df.sort_values(by='intake_date')
intakes_outcomes_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 69267   A664321  2013-10-01            Stray           Normal         Dog
# 29304   A664253  2013-10-01    Public Assist           Normal         Dog
# 40170   A664293  2013-10-01            Stray           Normal         Cat
# 53916   A664299  2013-10-01            Stray           Normal         Dog
# 83252   A664309  2013-10-01            Stray           Normal         Dog
# ...         ...         ...              ...              ...         ...
# 99012   A830150  2021-03-03            Stray           Normal         Dog
# 49474   A830183  2021-03-03            Stray             Sick         Dog
# 49554   A830131  2021-03-03            Stray             Sick         Dog
# 49486   A830158  2021-03-03            Stray           Normal         Dog
# 99108   A830181  2021-03-03  Owner Surrender           Normal         Cat
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# 69267          Female              1.0   2013-10-05         Transfer
# 29304            Male              2.0   2013-10-07  Adoption or RTO
# 40170            Male              0.0   2013-10-12         Transfer
# 53916            Male              0.0   2013-10-05         Transfer
# 83252            Male              1.0   2013-10-16         Transfer
# ...               ...              ...          ...              ...
# 99012            Male              2.0   2021-03-03  Still in center
# 49474          Female              0.0   2021-03-03  Still in center
# 49554            Male              0.0   2021-03-03  Still in center
# 49486            Male              2.0   2021-03-03  Still in center
# 99108          Female              4.0   2021-03-03  Still in center
#
#        age_upon_outcome  days_in_center
# 69267                 1               4
# 29304                 2               6
# 40170                 0              11
# 53916                 0               4
# 83252                 1              15
# ...                 ...             ...
# 99012                 2               0
# 49474                 0               0
# 49554                 0               0
# 49486                 2               0
# 99108                 4               0
#
# [96403 rows x 11 columns]

# %%
# Filter intake date between 2014-01-01 and 2020-12-31
intakes_outcomes_df = intakes_outcomes_df.loc[(intakes_outcomes_df['intake_date'] >= '2014-01-01') & (intakes_outcomes_df['intake_date'] <= '2020-12-31')]
intakes_outcomes_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 6233    A670083  2014-01-01            Stray           Normal         Dog
# 9569    A670077  2014-01-01    Public Assist           Normal         Dog
# 91252   A670032  2014-01-01            Stray           Normal         Dog
# 82271   A670075  2014-01-01  Owner Surrender           Normal         Cat
# 87372   A670055  2014-01-01            Stray           Normal         Dog
# ...         ...         ...              ...              ...         ...
# 16207   A827802  2020-12-31  Owner Surrender           Normal         Dog
# 48964   A827240  2020-12-31            Stray           Normal         Cat
# 49461   A827796  2020-12-31  Owner Surrender             Sick         Cat
# 49577   A827808  2020-12-31            Stray           Normal         Dog
# 48948   A827811  2020-12-31            Stray           Normal         Dog
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# 6233           Female              0.0   2014-01-07  Adoption or RTO
# 9569             Male              1.0   2014-01-19         Transfer
# 91252          Female              6.0   2014-01-01  Adoption or RTO
# 82271          Female              6.0   2014-01-16  Adoption or RTO
# 87372            Male              5.0   2014-01-05  Adoption or RTO
# ...               ...              ...          ...              ...
# 16207            Male             11.0   2021-01-05       Euthanasia
# 48964            Male              1.0   2021-01-07  Adoption or RTO
# 49461            Male              0.0   2020-12-31  Still in center
# 49577          Female              2.0   2020-12-31  Still in center
# 48948            Male              7.0   2021-01-06         Transfer
#
#        age_upon_outcome  days_in_center
# 6233                  0               6
# 9569                  1              18
# 91252                 6               0
# 82271                 6              15
# 87372                 5               4
# ...                 ...             ...
# 16207                11               5
# 48964                 1               7
# 49461                 0               0
# 49577                 2               0
# 48948                 7               6
#
# [92094 rows x 11 columns]

# %%
intakes_outcomes_df.to_csv('Data/clean_data.csv', index = False)

# %%
intakes_outcomes_df.to_sql(name='clean_data', con=engine, index=False)
