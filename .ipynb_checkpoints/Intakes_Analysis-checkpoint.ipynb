# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
from sqlalchemy import create_engine
from config import db_password
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Animal_Shelter"
engine = create_engine(db_string)

# %%
animal_center_df = pd.read_sql_table('clean_data', con=engine)
animal_center_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 0       A670083  2014-01-01            Stray           Normal         Dog
# 1       A670077  2014-01-01    Public Assist           Normal         Dog
# 2       A670032  2014-01-01            Stray           Normal         Dog
# 3       A670075  2014-01-01  Owner Surrender           Normal         Cat
# 4       A670055  2014-01-01            Stray           Normal         Dog
# ...         ...         ...              ...              ...         ...
# 91747   A827797  2020-12-31            Stray             Sick         Cat
# 91748   A827798  2020-12-31            Stray           Normal         Dog
# 91749   A827820  2020-12-31            Stray           Normal         Dog
# 91750   A827796  2020-12-31  Owner Surrender             Sick         Cat
# 91751   A827808  2020-12-31            Stray           Normal         Dog
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# ...

# %%
animal_center_df['intake_date'] = pd.to_datetime(animal_center_df['intake_date'],format='%m%Y').dt.to_period('M')
animal_center_df
# Out:
#       animal_id intake_date      intake_type intake_condition animal_type  \
# 0       A670083     2014-01            Stray           Normal         Dog
# 1       A670077     2014-01    Public Assist           Normal         Dog
# 2       A670032     2014-01            Stray           Normal         Dog
# 3       A670075     2014-01  Owner Surrender           Normal         Cat
# 4       A670055     2014-01            Stray           Normal         Dog
# ...         ...         ...              ...              ...         ...
# 91747   A827797     2020-12            Stray             Sick         Cat
# 91748   A827798     2020-12            Stray           Normal         Dog
# 91749   A827820     2020-12            Stray           Normal         Dog
# 91750   A827796     2020-12  Owner Surrender             Sick         Cat
# 91751   A827808     2020-12            Stray           Normal         Dog
#
#       sex_upon_intake  age_upon_intake outcome_date     outcome_type  \
# ...

# %%
number_of_intakes = pd.DataFrame(animal_center_df.intake_date.value_counts().reset_index().values, columns=["Date", "Number of Intakes"])
number_of_intakes
# Out:
#        Date Number of Intakes
# 0   2019-05              1739
# 1   2015-06              1679
# 2   2019-06              1656
# 3   2014-05              1651
# 4   2014-07              1596
# ..      ...               ...
# 79  2020-07               624
# 80  2020-11               490
# 81  2020-05               395
# 82  2020-12               383
# 83  2020-04               211
#
# [84 rows x 2 columns]

# %%
number_of_intakes = number_of_intakes.sort_values(by='Date')

# %%
number_of_intakes
# Out:
#        Date Number of Intakes
# 44  2014-01              1053
# 61  2014-02               919
# 42  2014-03              1094
# 25  2014-04              1254
# 3   2014-05              1651
# ..      ...               ...
# 76  2020-08               671
# 74  2020-09               693
# 77  2020-10               667
# 80  2020-11               490
# 82  2020-12               383
#
# [84 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
number_of_intakes.plot(x="Date", y="Number of Intakes")
plt.show()

# %%
number_of_intakes.dtypes
# Out:
# Date                 period[M]
# Number of Intakes       object
# dtype: object

# %%
# number of animals entering the shelter each year
number_of_intakes.groupby(number_of_intakes.Date.dt.year)['Number of Intakes'].sum().reset_index()
# Out:
#    Date Number of Intakes
# 0  2014             15177
# 1  2015             14424
# 2  2016             13312
# 3  2017             13342
# 4  2018             12937
# 5  2019             15298
# 6  2020              7262

# %%
# Avg number of animals entering the shelter each year
number_of_intakes.groupby(number_of_intakes.Date.dt.year)['Number of Intakes'].mean().reset_index()
# Out:
#    Date  Number of Intakes
# 0  2014        1264.750000
# 1  2015        1202.000000
# 2  2016        1109.333333
# 3  2017        1111.833333
# 4  2018        1078.083333
# 5  2019        1274.833333
# 6  2020         605.166667

# %%
# Max number of each year
number_of_intakes.groupby(number_of_intakes.Date.dt.year)['Number of Intakes'].max().reset_index()
# Out:
#    Date  Number of Intakes
# 0  2014               1651
# 1  2015               1679
# 2  2016               1582
# 3  2017               1475
# 4  2018               1374
# 5  2019               1739
# 6  2020                963

# %%
# Max month of each year
number_of_intakes.loc[((number_of_intakes['Date'].dt.year == 2014) & (number_of_intakes['Number of Intakes']==1651))|
                      ((number_of_intakes['Date'].dt.year == 2015) & (number_of_intakes['Number of Intakes']==1679))|
                      ((number_of_intakes['Date'].dt.year == 2016) & (number_of_intakes['Number of Intakes']==1582))|
                      ((number_of_intakes['Date'].dt.year == 2017) & (number_of_intakes['Number of Intakes']==1475))|
                      ((number_of_intakes['Date'].dt.year == 2018) & (number_of_intakes['Number of Intakes']==1374))|
                      ((number_of_intakes['Date'].dt.year == 2019) & (number_of_intakes['Number of Intakes']==1739))|
                      ((number_of_intakes['Date'].dt.year == 2020) & (number_of_intakes['Number of Intakes']==963)),
                      ['Date','Number of Intakes']]
# Out:
#        Date Number of Intakes
# 3   2014-05              1651
# 1   2015-06              1679
# 5   2016-05              1582
# 9   2017-05              1475
# 14  2018-06              1374
# 0   2019-05              1739
# 53  2020-01               963

# %%
# Min number of each year
number_of_intakes.groupby(number_of_intakes.Date.dt.year)['Number of Intakes'].min().reset_index()
# Out:
#    Date  Number of Intakes
# 0  2014                919
# 1  2015                851
# 2  2016                894
# 3  2017                880
# 4  2018                790
# 5  2019                834
# 6  2020                211

# %%
# Min month of each year
number_of_intakes.loc[((number_of_intakes['Date'].dt.year == 2014) & (number_of_intakes['Number of Intakes']==919))|
                      ((number_of_intakes['Date'].dt.year == 2015) & (number_of_intakes['Number of Intakes']==851))|
                      ((number_of_intakes['Date'].dt.year == 2016) & (number_of_intakes['Number of Intakes']==894))|
                      ((number_of_intakes['Date'].dt.year == 2017) & (number_of_intakes['Number of Intakes']==880))|
                      ((number_of_intakes['Date'].dt.year == 2018) & (number_of_intakes['Number of Intakes']==790))|
                      ((number_of_intakes['Date'].dt.year == 2019) & (number_of_intakes['Number of Intakes']==834))|
                      ((number_of_intakes['Date'].dt.year == 2020) & (number_of_intakes['Number of Intakes']==211)),
                      ['Date','Number of Intakes']]
# Out:
#        Date Number of Intakes
# 61  2014-02               919
# 69  2015-02               851
# 63  2016-02               894
# 67  2017-11               880
# 73  2018-02               790
# 71  2019-02               834
# 83  2020-04               211
